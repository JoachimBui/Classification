# %%
# Import packages
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import tree
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load and preprocess data

# %%
# Load datasets
df = pd.read_excel('Dokumenter\ChildrenWristFeaturesV2_TSF_new.xlsx')
df.fillna(df.mean(), inplace=True)

# %%
# Initialize features and targets/labels
X = df.iloc[:, 1:32]
Y = df.iloc[:, 32]

# Splits datasets into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Data preprocessing, scaling datasets/standardization
scal_data = StandardScaler()
X_train = scal_data.fit_transform(X_train)
X_test = scal_data.transform(X_test)

# %% [markdown]
# # Hyperparameter tuning

# %%
# Try different range of values
# Quality of a split
criterion = ['gini', 'entropy']
# Strategy used to split at each node
splitter = ['best', 'random']
# Number of features to consider at every split
max_features = range(1, 32, 5)
# Maximum depth
max_depth = range(50, 1001, 50)
# Minimun number before split
#min_samples_split = range(2, 20, 5)
# Minimun number for a leaf node
#min_samples_leaf = range(1, 10, 3)

# Create dictionary to store the hyperparameters
param_grid = { 'criterion': criterion,
               'splitter': splitter,
               'max_features': max_features,
               'max_depth': max_depth}

# Base model
dt = tree.DecisionTreeClassifier()

# %% [markdown]
# # First run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
dt_grid = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, verbose=2)
dt_grid.fit(X_train, y_train)
print(dt_grid.best_params_)
print(dt_grid.best_score_)
# Out:
# Fitting 5 folds for each of 156 candidates, totalling 780 fits
# [CV] max_depth=30, max_features=1, splitter=best .....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ...... max_depth=30, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=30, max_features=1, splitter=best .....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ...... max_depth=30, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=30, max_features=1, splitter=best .....................
# [CV] ...... max_depth=30, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=30, max_features=1, splitter=best .....................
# [CV] ...... max_depth=30, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=30, max_features=1, splitter=best .....................
# [CV] ...... max_depth=30, max_features=1, splitter=best, total=   0.3s
# ...

# %% [markdown]
# # Second run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
dt_grid = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, verbose=2)
dt_grid.fit(X_train, y_train)
print(dt_grid.best_params_)
print(dt_grid.best_score_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] max_depth=90, max_features=1, splitter=best .....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ...... max_depth=90, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=90, max_features=1, splitter=best .....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ...... max_depth=90, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=90, max_features=1, splitter=best .....................
# [CV] ...... max_depth=90, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=90, max_features=1, splitter=best .....................
# [CV] ...... max_depth=90, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=90, max_features=1, splitter=best .....................
# [CV] ...... max_depth=90, max_features=1, splitter=best, total=   0.3s
# ...

# %% [markdown]
# # Third run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
dt_grid = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, verbose=2)
dt_grid.fit(X_train, y_train)
print(dt_grid.best_params_)
print(dt_grid.best_score_)
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# [CV] max_depth=100, max_features=1, splitter=best ....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=100, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=100, max_features=1, splitter=best ....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ..... max_depth=100, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=100, max_features=1, splitter=best ....................
# [CV] ..... max_depth=100, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=100, max_features=1, splitter=best ....................
# [CV] ..... max_depth=100, max_features=1, splitter=best, total=   0.3s
# [CV] max_depth=100, max_features=1, splitter=best ....................
# [CV] ..... max_depth=100, max_features=1, splitter=best, total=   0.3s
# ...

# %% [markdown]
# # Fourth run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
dt_grid = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, verbose=2)
dt_grid.fit(X_train, y_train)
print(dt_grid.best_params_)
print(dt_grid.best_score_)
# Out:
# Fitting 5 folds for each of 2160 candidates, totalling 10800 fits
# [CV] criterion=gini, max_depth=100, max_features=1, min_samples_leaf=1, min_samples_split=2, splitter=best
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=gini, max_depth=100, max_features=1, min_samples_leaf=1, min_samples_split=2, splitter=best, total=   0.3s
# [CV] criterion=gini, max_depth=100, max_features=1, min_samples_leaf=1, min_samples_split=2, splitter=best
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=100, max_features=1, min_samples_leaf=1, min_samples_split=2, splitter=best, total=   0.3s
# [CV] criterion=gini, max_depth=100, max_features=1, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV]  criterion=gini, max_depth=100, max_features=1, min_samples_leaf=1, min_samples_split=2, splitter=best, total=   0.3s
# ...

# %% [markdown]
# # Fifth run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
dt_grid = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, verbose=2)
dt_grid.fit(X_train, y_train)
print(dt_grid.best_params_)
print(dt_grid.best_score_)
# Out:
# Fitting 5 folds for each of 560 candidates, totalling 2800 fits
# [CV] criterion=gini, max_depth=50, max_features=1, splitter=best .....
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=gini, max_depth=50, max_features=1, splitter=best, total=   0.3s
# [CV] criterion=gini, max_depth=50, max_features=1, splitter=best .....
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=50, max_features=1, splitter=best, total=   0.3s
# [CV] criterion=gini, max_depth=50, max_features=1, splitter=best .....
# [CV]  criterion=gini, max_depth=50, max_features=1, splitter=best, total=   0.3s
# [CV] criterion=gini, max_depth=50, max_features=1, splitter=best .....
# [CV]  criterion=gini, max_depth=50, max_features=1, splitter=best, total=   0.3s
# [CV] criterion=gini, max_depth=50, max_features=1, splitter=best .....
# ...

# %% [markdown]
# # Features analyzing

# %% [markdown]
# # Second run

# %%
# Analyze features using feature importance
importance = dt_grid.best_estimator_.feature_importances_
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Plot feature importance chart
plt.figure(figsize=(10, 10))
plt.barh(range(31, 0, -1), dt_grid.best_estimator_.feature_importances_[0:31])
plt.yticks(range(31, 0, -1), df.columns.tolist()[1:32])
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)
# Out:
# Feature: 0, Score: 0.19004
# Feature: 1, Score: 0.04583
# Feature: 2, Score: 0.02846
# Feature: 3, Score: 0.04887
# Feature: 4, Score: 0.02199
# Feature: 5, Score: 0.01997
# Feature: 6, Score: 0.02045
# Feature: 7, Score: 0.01524
# Feature: 8, Score: 0.04639
# Feature: 9, Score: 0.04427
# Feature: 10, Score: 0.03473
# Feature: 11, Score: 0.12971
# Feature: 12, Score: 0.04253
# Feature: 13, Score: 0.01049
# Feature: 14, Score: 0.03362
# Feature: 15, Score: 0.02346
# Feature: 16, Score: 0.00797
# Feature: 17, Score: 0.02723
# Feature: 18, Score: 0.01424
# Feature: 19, Score: 0.00956
# Feature: 20, Score: 0.01561
# Feature: 21, Score: 0.02055
# Feature: 22, Score: 0.02667
# Feature: 23, Score: 0.00484
# Feature: 24, Score: 0.00936
# Feature: 25, Score: 0.01594
# Feature: 26, Score: 0.02902
# Feature: 27, Score: 0.01038
# Feature: 28, Score: 0.01727
# Feature: 29, Score: 0.01262
# Feature: 30, Score: 0.02274

# %% [markdown]
# # Fourth run

# %%
# Analyze features using feature importance
importance = dt_grid.best_estimator_.feature_importances_
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Plot feature importance chart
plt.figure(figsize=(10, 10))
plt.barh(range(31, 0, -1), dt_grid.best_estimator_.feature_importances_[0:31])
plt.yticks(range(31, 0, -1), df.columns.tolist()[1:32])
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)
# Out:
# Feature: 0, Score: 0.32815
# Feature: 1, Score: 0.03457
# Feature: 2, Score: 0.02005
# Feature: 3, Score: 0.03419
# Feature: 4, Score: 0.01980
# Feature: 5, Score: 0.01461
# Feature: 6, Score: 0.01586
# Feature: 7, Score: 0.01391
# Feature: 8, Score: 0.03623
# Feature: 9, Score: 0.03459
# Feature: 10, Score: 0.02158
# Feature: 11, Score: 0.10214
# Feature: 12, Score: 0.03313
# Feature: 13, Score: 0.02071
# Feature: 14, Score: 0.02881
# Feature: 15, Score: 0.02574
# Feature: 16, Score: 0.00600
# Feature: 17, Score: 0.03221
# Feature: 18, Score: 0.00999
# Feature: 19, Score: 0.00687
# Feature: 20, Score: 0.00494
# Feature: 21, Score: 0.01254
# Feature: 22, Score: 0.03166
# Feature: 23, Score: 0.00501
# Feature: 24, Score: 0.00968
# Feature: 25, Score: 0.01249
# Feature: 26, Score: 0.02627
# Feature: 27, Score: 0.01073
# Feature: 28, Score: 0.01369
# Feature: 29, Score: 0.01406
# Feature: 30, Score: 0.01978

# %% [markdown]
# # Fifth run

# %%
# Analyze features using feature importance
importance = dt_grid.best_estimator_.feature_importances_
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Plot feature importance chart
plt.figure(figsize=(10, 10))
plt.barh(range(31, 0, -1), dt_grid.best_estimator_.feature_importances_[0:31])
plt.yticks(range(31, 0, -1), df.columns.tolist()[1:32])
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)
# Out:
# Feature: 0, Score: 0.32837
# Feature: 1, Score: 0.03643
# Feature: 2, Score: 0.01992
# Feature: 3, Score: 0.03278
# Feature: 4, Score: 0.01958
# Feature: 5, Score: 0.01469
# Feature: 6, Score: 0.01587
# Feature: 7, Score: 0.01373
# Feature: 8, Score: 0.03539
# Feature: 9, Score: 0.03497
# Feature: 10, Score: 0.02204
# Feature: 11, Score: 0.10220
# Feature: 12, Score: 0.03298
# Feature: 13, Score: 0.00563
# Feature: 14, Score: 0.02850
# Feature: 15, Score: 0.02565
# Feature: 16, Score: 0.00605
# Feature: 17, Score: 0.03198
# Feature: 18, Score: 0.01308
# Feature: 19, Score: 0.00667
# Feature: 20, Score: 0.02042
# Feature: 21, Score: 0.00934
# Feature: 22, Score: 0.03244
# Feature: 23, Score: 0.00543
# Feature: 24, Score: 0.01222
# Feature: 25, Score: 0.01208
# Feature: 26, Score: 0.02596
# Feature: 27, Score: 0.00961
# Feature: 28, Score: 0.01289
# Feature: 29, Score: 0.01478
# Feature: 30, Score: 0.01833

# %% [markdown]
# # New run with data from features

# %% [markdown]
# # Second run

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score
df_features = df.iloc[:, 1:32]
X_new = df_features.iloc[:, importance>=0.025]
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new, Y, test_size=0.2, random_state=42)
dt_new = tree.DecisionTreeClassifier(max_features=13, max_depth=150)
dt_new.fit(X_train_new, y_train_new)
pred_train = dt_new.predict(X_train_new)
pred_test = dt_new.predict(X_test_new)
print(dt_new.score(X_train_new, y_train_new))
print(dt_new.score(X_test_new, y_test_new))

auc_tr = roc_auc_score(y_train_new, dt_new.predict_proba(X_train_new), average='macro', multi_class='ovr')
auc_ts = roc_auc_score(y_test_new, dt_new.predict_proba(X_test_new), average='macro', multi_class='ovr')

print(auc_tr)
print(auc_ts)

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_new, pred_test))
# Out:
# 1.0
# 0.8021660385642677
# 1.0
# 0.8785992167594485
# [[ 1409    39     8     0     0     1     0     0     0    24   169]
#  [   28  1402    29     0     0     1     0     0     1    12   172]
#  [    8    33  1406     2     0    11     1     3     9    10   181]
#  [    0     0     2  1303    69    10    17     9     3     0   265]
#  [    0     0     0    71  1234    63    32    15     9     0   227]
#  [    0     0     2    12    65  1295    50    15    33     1   215]
#  [    0     0     2    24    30    51  1180    19   116     0   257]
#  [    0     0     0     9    16    22    23  1297     9     0   300]
#  [    2     0     2     4    20    37   122    12   705     0   163]
#  [   28    28    10     0     0     0     0     0     1   590    94]
#  [  145   185   191   289   259   195   275   298   158    84 10103]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train_new, pred_train))
print(classification_report(y_test_new, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      6750
#            2       1.00      1.00      1.00      6755
#            3       1.00      1.00      1.00      6736
#            4       1.00      1.00      1.00      6722
#            5       1.00      1.00      1.00      6749
#            6       1.00      1.00      1.00      6712
#            7       1.00      1.00      1.00      6721
#            8       1.00      1.00      1.00      6724
#            9       1.00      1.00      1.00      4213
#           10       1.00      1.00      1.00      3042
#           12       1.00      1.00      1.00     48198
#
#     accuracy                           1.00    109322
#    macro avg       1.00      1.00      1.00    109322
# weighted avg       1.00      1.00      1.00    109322
#
#               precision    recall  f1-score   support
#
#            1       0.87      0.85      0.86      1650
# ...

# %% [markdown]
# # Fifth run

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score
df_features = df.iloc[:, 1:32]
X_new = df_features.iloc[:, importance>=0.02]
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new, Y, test_size=0.2, random_state=42)
dt_new = tree.DecisionTreeClassifier(criterion='entropy', max_features=14, max_depth=350)
dt_clf = OneVsRestClassifier(dt_new)
dt_clf.fit(X_train_new, y_train_new)

#dt_clf = dt_clf.predict_proba(X_test_new)

pred_train = dt_clf.predict(X_train_new)
pred_test = dt_clf.predict(X_test_new)

print(dt_clf.score(X_train_new, y_train_new))
print(dt_clf.score(X_test_new, y_test_new))

auc_tr = roc_auc_score(y_train_new, dt_clf.predict_proba(X_train_new), average='macro', multi_class='ovr')
auc_ts = roc_auc_score(y_test_new, dt_clf.predict_proba(X_test_new), average='macro', multi_class='ovr')
#auc_ts = roc_auc_score(y_test_new, dt_clf, average='macro', multi_class='ovr')

print(auc_tr)
print(auc_ts)

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_new, pred_test))
# Out:
# 1.0
# 0.7934579781200835
# C:\Anaconda\lib\site-packages\sklearn\multiclass.py:382: RuntimeWarning: invalid value encountered in true_divide
#   Y /= np.sum(Y, axis=1)[:, np.newaxis]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-eabf952f4a46> in <module>
#      24
#      25 auc_tr = roc_auc_score(y_train_new, dt_clf.predict_proba(X_train_new), average='macro', multi_class='ovr')
# ---> 26 auc_ts = roc_auc_score(y_test_new, dt_clf.predict_proba(X_test_new), average='macro', multi_class='ovr')
#      27 #auc_ts = roc_auc_score(y_test_new, dt_clf, average='macro', multi_class='ovr')
#      28 #auc_tr = roc_auc_score(y_train_new, dt_new.predict_proba(X_train_new), average='macro', multi_class='ovr')
#
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

correlation = df_features.corr()

plt.figure(figsize=(25,15))
sns.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot:>
