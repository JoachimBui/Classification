# %%
# Import packages
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import neighbors
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load and preprocess data

# %%
# Load datasets
df = pd.read_excel('Dokumenter\ChildrenWristFeaturesV2_TSF_new.xlsx')
df.fillna(df.mean(), inplace=True)

# %%
# Initialize features and targets/labels
X = df.iloc[:, 1:32]
Y = df.iloc[:, 32]

# Splits datasets into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Data preprocessing, scaling datasets/standardization
scal_data = StandardScaler()
X_train = scal_data.fit_transform(X_train)
X_test = scal_data.transform(X_test)

# %% [markdown]
# # Hyperparameter tuning

# %%
# Try different range of values
# Number of neighbors
#n_neighbors = [2, 5, 7, 10, 15]
# Number of features to consider at every split
weights = ['uniform', 'distance']
# Maximum depth
algorithm = ['ball_tree', 'kd_tree', 'brute', 'auto']
# Leaf size passed to BallTree or KDTree
leaf_size = [1, 5, 10, 15]
# Power parameter for the Minkowski metric
p = [1, 2]

# Create dictionary to store the hyperparameters
param_grid = { 'weights': weights,
               'algorithm': algorithm,
               'leaf_size': leaf_size,
               'p': p}

# Base model
knn = neighbors.KNeighborsClassifier()

# %% [markdown]
# # First run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
knn_grid = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5, verbose=2)
knn_grid.fit(X_train, y_train)
print(knn_grid.best_params_)
print(knn_grid.best_score_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] algorithm=ball_tree, n_neighbors=2, weights=uniform .............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=uniform .............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.6min remaining:    0.0s
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=uniform, total= 1.4min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=uniform, total= 1.4min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=uniform, total= 1.4min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=uniform, total= 1.3min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=distance, total= 1.4min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, n_neighbors=2, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=5, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=5, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=uniform .............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=uniform, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=7, weights=distance ............
# [CV]  algorithm=ball_tree, n_neighbors=7, weights=distance, total= 1.5min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=uniform, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=uniform, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=10, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=10, weights=distance, total= 1.6min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=uniform, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=uniform, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=uniform, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=uniform, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=uniform ............
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=uniform, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=distance, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=distance, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=distance, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=distance, total= 1.7min
# [CV] algorithm=ball_tree, n_neighbors=15, weights=distance ...........
# [CV]  algorithm=ball_tree, n_neighbors=15, weights=distance, total= 1.7min
# [CV] algorithm=kd_tree, n_neighbors=2, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=uniform, total=  17.2s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=uniform, total=  16.9s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=uniform, total=  17.0s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=uniform, total=  16.9s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=uniform, total=  16.8s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=distance, total=  17.2s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=distance, total=  16.9s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=distance, total=  16.2s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=distance, total=  16.3s
# [CV] algorithm=kd_tree, n_neighbors=2, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=2, weights=distance, total=  15.8s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=uniform, total=  22.7s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=uniform, total=  22.6s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=uniform, total=  22.7s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=uniform, total=  22.4s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=uniform, total=  22.1s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=distance, total=  21.8s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=distance, total=  21.7s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=distance, total=  21.6s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=distance, total=  21.4s
# [CV] algorithm=kd_tree, n_neighbors=5, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=5, weights=distance, total=  21.3s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=uniform, total=  25.0s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=uniform, total=  24.9s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=uniform, total=  25.3s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=uniform, total=  25.1s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=uniform ...............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=uniform, total=  24.5s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=distance, total=  24.0s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=distance, total=  24.1s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=distance, total=  24.7s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=distance, total=  24.8s
# [CV] algorithm=kd_tree, n_neighbors=7, weights=distance ..............
# [CV]  algorithm=kd_tree, n_neighbors=7, weights=distance, total=  23.8s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=uniform, total=  28.9s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=uniform, total=  28.5s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=uniform, total=  28.9s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=uniform, total=  29.2s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=uniform, total=  30.6s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=distance, total=  28.5s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=distance, total=  27.8s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=distance, total=  27.5s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=distance, total=  27.0s
# [CV] algorithm=kd_tree, n_neighbors=10, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=10, weights=distance, total=  27.6s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=uniform, total=  33.0s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=uniform, total=  33.0s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=uniform, total=  33.6s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=uniform, total=  32.9s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=uniform ..............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=uniform, total=  32.8s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=distance, total=  32.8s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=distance, total=  31.8s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=distance, total=  32.3s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=distance, total=  32.7s
# [CV] algorithm=kd_tree, n_neighbors=15, weights=distance .............
# [CV]  algorithm=kd_tree, n_neighbors=15, weights=distance, total=  31.9s
# [CV] algorithm=brute, n_neighbors=2, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=2, weights=uniform, total=  42.0s
# [CV] algorithm=brute, n_neighbors=2, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=2, weights=uniform, total=  43.0s
# [CV] algorithm=brute, n_neighbors=2, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=2, weights=uniform, total=  41.6s
# [CV] algorithm=brute, n_neighbors=2, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=2, weights=uniform, total=  43.6s
# [CV] algorithm=brute, n_neighbors=2, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=2, weights=uniform, total=  41.6s
# [CV] algorithm=brute, n_neighbors=2, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=2, weights=distance, total=  41.6s
# [CV] algorithm=brute, n_neighbors=2, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=2, weights=distance, total=  41.6s
# [CV] algorithm=brute, n_neighbors=2, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=2, weights=distance, total=  38.8s
# [CV] algorithm=brute, n_neighbors=2, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=2, weights=distance, total=  38.9s
# [CV] algorithm=brute, n_neighbors=2, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=2, weights=distance, total=  38.9s
# [CV] algorithm=brute, n_neighbors=5, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=5, weights=uniform, total=  50.3s
# [CV] algorithm=brute, n_neighbors=5, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=5, weights=uniform, total=  50.1s
# [CV] algorithm=brute, n_neighbors=5, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=5, weights=uniform, total=  50.8s
# [CV] algorithm=brute, n_neighbors=5, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=5, weights=uniform, total=  49.4s
# [CV] algorithm=brute, n_neighbors=5, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=5, weights=uniform, total=  51.1s
# [CV] algorithm=brute, n_neighbors=5, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=5, weights=distance, total=  52.1s
# [CV] algorithm=brute, n_neighbors=5, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=5, weights=distance, total=  51.0s
# [CV] algorithm=brute, n_neighbors=5, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=5, weights=distance, total=  51.7s
# [CV] algorithm=brute, n_neighbors=5, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=5, weights=distance, total=  49.4s
# [CV] algorithm=brute, n_neighbors=5, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=5, weights=distance, total=  51.2s
# [CV] algorithm=brute, n_neighbors=7, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=7, weights=uniform, total=  51.2s
# [CV] algorithm=brute, n_neighbors=7, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=7, weights=uniform, total=  52.4s
# [CV] algorithm=brute, n_neighbors=7, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=7, weights=uniform, total=  52.2s
# [CV] algorithm=brute, n_neighbors=7, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=7, weights=uniform, total=  51.8s
# [CV] algorithm=brute, n_neighbors=7, weights=uniform .................
# [CV] .. algorithm=brute, n_neighbors=7, weights=uniform, total=  51.8s
# [CV] algorithm=brute, n_neighbors=7, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=7, weights=distance, total=  50.5s
# [CV] algorithm=brute, n_neighbors=7, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=7, weights=distance, total=  47.7s
# [CV] algorithm=brute, n_neighbors=7, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=7, weights=distance, total=  49.7s
# [CV] algorithm=brute, n_neighbors=7, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=7, weights=distance, total=  49.0s
# [CV] algorithm=brute, n_neighbors=7, weights=distance ................
# [CV] . algorithm=brute, n_neighbors=7, weights=distance, total=  49.2s
# [CV] algorithm=brute, n_neighbors=10, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=10, weights=uniform, total=  49.7s
# [CV] algorithm=brute, n_neighbors=10, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=10, weights=uniform, total=  49.4s
# [CV] algorithm=brute, n_neighbors=10, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=10, weights=uniform, total=  51.5s
# [CV] algorithm=brute, n_neighbors=10, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=10, weights=uniform, total=  51.0s
# [CV] algorithm=brute, n_neighbors=10, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=10, weights=uniform, total=  52.0s
# [CV] algorithm=brute, n_neighbors=10, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=10, weights=distance, total=  50.7s
# [CV] algorithm=brute, n_neighbors=10, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=10, weights=distance, total=  50.5s
# [CV] algorithm=brute, n_neighbors=10, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=10, weights=distance, total=  53.7s
# [CV] algorithm=brute, n_neighbors=10, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=10, weights=distance, total=  52.1s
# [CV] algorithm=brute, n_neighbors=10, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=10, weights=distance, total=  51.7s
# [CV] algorithm=brute, n_neighbors=15, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=15, weights=uniform, total=  54.2s
# [CV] algorithm=brute, n_neighbors=15, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=15, weights=uniform, total=  51.8s
# [CV] algorithm=brute, n_neighbors=15, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=15, weights=uniform, total=  50.9s
# [CV] algorithm=brute, n_neighbors=15, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=15, weights=uniform, total=  49.0s
# [CV] algorithm=brute, n_neighbors=15, weights=uniform ................
# [CV] . algorithm=brute, n_neighbors=15, weights=uniform, total=  50.7s
# [CV] algorithm=brute, n_neighbors=15, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=15, weights=distance, total=  47.5s
# [CV] algorithm=brute, n_neighbors=15, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=15, weights=distance, total=  48.0s
# [CV] algorithm=brute, n_neighbors=15, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=15, weights=distance, total=  52.2s
# [CV] algorithm=brute, n_neighbors=15, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=15, weights=distance, total=  48.2s
# [CV] algorithm=brute, n_neighbors=15, weights=distance ...............
# [CV]  algorithm=brute, n_neighbors=15, weights=distance, total=  50.6s
# [CV] algorithm=auto, n_neighbors=2, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=2, weights=uniform, total=  17.3s
# [CV] algorithm=auto, n_neighbors=2, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=2, weights=uniform, total=  17.7s
# [CV] algorithm=auto, n_neighbors=2, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=2, weights=uniform, total=  17.3s
# [CV] algorithm=auto, n_neighbors=2, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=2, weights=uniform, total=  17.0s
# [CV] algorithm=auto, n_neighbors=2, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=2, weights=uniform, total=  17.3s
# [CV] algorithm=auto, n_neighbors=2, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=2, weights=distance, total=  16.5s
# [CV] algorithm=auto, n_neighbors=2, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=2, weights=distance, total=  16.4s
# [CV] algorithm=auto, n_neighbors=2, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=2, weights=distance, total=  16.2s
# [CV] algorithm=auto, n_neighbors=2, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=2, weights=distance, total=  15.9s
# [CV] algorithm=auto, n_neighbors=2, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=2, weights=distance, total=  15.9s
# [CV] algorithm=auto, n_neighbors=5, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=5, weights=uniform, total=  22.6s
# [CV] algorithm=auto, n_neighbors=5, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=5, weights=uniform, total=  22.5s
# [CV] algorithm=auto, n_neighbors=5, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=5, weights=uniform, total=  22.6s
# [CV] algorithm=auto, n_neighbors=5, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=5, weights=uniform, total=  22.5s
# [CV] algorithm=auto, n_neighbors=5, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=5, weights=uniform, total=  22.2s
# [CV] algorithm=auto, n_neighbors=5, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=5, weights=distance, total=  21.6s
# [CV] algorithm=auto, n_neighbors=5, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=5, weights=distance, total=  21.5s
# [CV] algorithm=auto, n_neighbors=5, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=5, weights=distance, total=  21.7s
# [CV] algorithm=auto, n_neighbors=5, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=5, weights=distance, total=  21.3s
# [CV] algorithm=auto, n_neighbors=5, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=5, weights=distance, total=  21.1s
# [CV] algorithm=auto, n_neighbors=7, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=7, weights=uniform, total=  25.0s
# [CV] algorithm=auto, n_neighbors=7, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=7, weights=uniform, total=  25.0s
# [CV] algorithm=auto, n_neighbors=7, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=7, weights=uniform, total=  25.0s
# [CV] algorithm=auto, n_neighbors=7, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=7, weights=uniform, total=  24.7s
# [CV] algorithm=auto, n_neighbors=7, weights=uniform ..................
# [CV] ... algorithm=auto, n_neighbors=7, weights=uniform, total=  24.5s
# [CV] algorithm=auto, n_neighbors=7, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=7, weights=distance, total=  24.0s
# [CV] algorithm=auto, n_neighbors=7, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=7, weights=distance, total=  23.9s
# [CV] algorithm=auto, n_neighbors=7, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=7, weights=distance, total=  24.2s
# [CV] algorithm=auto, n_neighbors=7, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=7, weights=distance, total=  24.0s
# [CV] algorithm=auto, n_neighbors=7, weights=distance .................
# [CV] .. algorithm=auto, n_neighbors=7, weights=distance, total=  23.7s
# [CV] algorithm=auto, n_neighbors=10, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=10, weights=uniform, total=  28.2s
# [CV] algorithm=auto, n_neighbors=10, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=10, weights=uniform, total=  28.3s
# [CV] algorithm=auto, n_neighbors=10, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=10, weights=uniform, total=  28.3s
# [CV] algorithm=auto, n_neighbors=10, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=10, weights=uniform, total=  27.7s
# [CV] algorithm=auto, n_neighbors=10, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=10, weights=uniform, total=  27.7s
# [CV] algorithm=auto, n_neighbors=10, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=10, weights=distance, total=  27.3s
# [CV] algorithm=auto, n_neighbors=10, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=10, weights=distance, total=  27.1s
# [CV] algorithm=auto, n_neighbors=10, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=10, weights=distance, total=  27.2s
# [CV] algorithm=auto, n_neighbors=10, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=10, weights=distance, total=  27.0s
# [CV] algorithm=auto, n_neighbors=10, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=10, weights=distance, total=  26.6s
# [CV] algorithm=auto, n_neighbors=15, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=15, weights=uniform, total=  32.2s
# [CV] algorithm=auto, n_neighbors=15, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=15, weights=uniform, total=  32.0s
# [CV] algorithm=auto, n_neighbors=15, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=15, weights=uniform, total=  33.6s
# [CV] algorithm=auto, n_neighbors=15, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=15, weights=uniform, total=  31.9s
# [CV] algorithm=auto, n_neighbors=15, weights=uniform .................
# [CV] .. algorithm=auto, n_neighbors=15, weights=uniform, total=  31.8s
# [CV] algorithm=auto, n_neighbors=15, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=15, weights=distance, total=  31.2s
# [CV] algorithm=auto, n_neighbors=15, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=15, weights=distance, total=  31.1s
# [CV] algorithm=auto, n_neighbors=15, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=15, weights=distance, total=  31.4s
# [CV] algorithm=auto, n_neighbors=15, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=15, weights=distance, total=  30.9s
# [CV] algorithm=auto, n_neighbors=15, weights=distance ................
# [CV] . algorithm=auto, n_neighbors=15, weights=distance, total=  30.6s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed: 158.9min finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-99bcf8dd6948> in <module>
#       2 kn_grid = GridSearchCV(estimator=kn, param_grid=param_grid, cv=5, verbose=2)
#       3 kn_grid.fit(X_train, y_train)
# ----> 4 print(dt_grid.best_params_)
#       5 print(dt_grid.best_score_)
#
# NameError: name 'dt_grid' is not defined

# %%
print(knn_grid.best_params_)
print(knn_grid.best_score_)
# Out:
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'weights': 'distance'}
# 0.6865772550332768

# %% [markdown]
# # Second run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
knn_grid = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5, verbose=2)
knn_grid.fit(X_train, y_train)
print(knn_grid.best_params_)
print(knn_grid.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance, total=  23.6s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   23.5s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance, total=  23.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance, total=  23.6s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance, total=  23.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=1, weights=distance, total=  22.7s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance, total=  37.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance, total=  35.9s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance, total=  37.1s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance, total=  36.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=2, p=2, weights=distance, total=  35.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance, total=  27.7s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance, total=  28.1s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance, total=  30.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance, total=  29.4s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=1, weights=distance, total=  29.1s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance, total=  45.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance, total=  45.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance, total=  52.9s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance, total=  46.4s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=5, p=2, weights=distance, total=  55.3s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance, total=  37.8s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance, total=  35.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance, total=  37.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance, total=  37.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=1, weights=distance, total=  36.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance, total=  55.1s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance, total=  51.4s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance, total=  56.8s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance, total=  55.5s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=7, p=2, weights=distance, total=  53.5s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance, total=  40.4s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance, total=  39.7s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance, total=  40.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance, total=  40.8s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=1, weights=distance, total=  39.2s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance, total=  59.8s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=10, p=2, weights=distance, total=  57.8s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance, total=  44.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance, total=  43.8s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance, total=  45.1s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance, total=  44.1s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=1, weights=distance, total=  41.9s
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance, total=  32.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance, total=  33.1s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance, total=  32.9s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance, total=  32.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=1, weights=distance, total=  31.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance, total=  47.1s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance, total=  48.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance, total=  48.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance, total=  47.1s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=2, p=2, weights=distance, total=  46.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance, total=  36.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance, total=  37.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance, total=  38.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance, total=  38.1s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=1, weights=distance, total=  36.8s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance, total=  56.7s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance, total=  56.1s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance, total=  57.5s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance, total=  55.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=5, p=2, weights=distance, total=  54.7s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance, total=  40.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance, total=  39.6s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance, total=  40.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance, total=  40.7s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=1, weights=distance, total=  39.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance, total=  58.9s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance, total=  59.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=7, p=2, weights=distance, total=  59.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance, total=  42.6s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance, total=  43.1s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance, total=  47.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance, total=  45.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=1, weights=distance, total=  42.2s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=10, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance, total=  46.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance, total=  47.7s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance, total=  48.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance, total=  46.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=1, weights=distance, total=  45.6s
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_neighbors=15, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance, total=  36.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance, total=  37.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance, total=  37.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance, total=  37.5s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=1, weights=distance, total=  37.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance, total=  53.8s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance, total=  54.2s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance, total=  55.7s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance, total=  53.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=2, p=2, weights=distance, total=  53.1s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance, total=  42.8s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance, total=  43.9s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance, total=  45.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance, total=  41.3s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=1, weights=distance, total=  43.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=5, p=2, weights=distance, total=  57.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance, total=  46.3s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance, total=  46.9s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance, total=  47.2s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance, total=  45.9s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=1, weights=distance, total=  45.1s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=7, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance, total=  48.9s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance, total=  50.3s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance, total=  50.0s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance, total=  49.5s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=1, weights=distance, total=  47.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=10, p=2, weights=distance, total= 1.1min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance, total=  51.0s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance, total=  52.5s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance, total=  52.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance, total=  55.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=1, weights=distance, total=  52.8s
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance, total= 1.3min
# [CV] algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_neighbors=15, p=2, weights=distance, total= 1.3min
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed: 124.6min finished
# {'algorithm': 'ball_tree', 'leaf_size': 1, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.7316185012160491

# %% [markdown]
# # Third run

# %%
# Use the GridSearchCV function to cross validate and find the best values for each hyperparameter
knn_grid = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5, verbose=2)
knn_grid.fit(X_train, y_train)
print(knn_grid.best_params_)
print(knn_grid.best_score_)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=uniform ..........
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=uniform, total=  30.2s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=uniform ..........
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   30.1s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=uniform, total=  28.9s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=uniform, total=  28.3s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=uniform, total=  28.0s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=uniform, total=  29.1s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=distance, total=  26.9s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=distance, total=  26.9s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=distance, total=  27.5s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=distance, total=  27.0s
# [CV] algorithm=ball_tree, leaf_size=1, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=1, weights=distance, total=  27.2s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=uniform, total=  42.6s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=uniform, total=  42.7s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=uniform, total=  45.1s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=uniform, total=  43.5s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=uniform, total=  42.4s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=distance, total=  43.1s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=distance, total=  42.6s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=distance, total=  43.6s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=distance, total=  42.8s
# [CV] algorithm=ball_tree, leaf_size=1, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=1, p=2, weights=distance, total=  43.0s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=uniform, total=  35.3s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=uniform, total=  36.3s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=uniform, total=  36.4s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=uniform, total=  35.8s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=uniform, total=  37.1s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=distance, total=  34.6s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=distance, total=  34.9s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=distance, total=  34.9s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=distance, total=  34.0s
# [CV] algorithm=ball_tree, leaf_size=5, p=1, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=1, weights=distance, total=  33.2s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=uniform, total=  53.7s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=uniform, total=  52.1s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=uniform, total=  52.0s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=uniform, total=  50.3s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=uniform ..........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=uniform, total=  52.2s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=distance, total=  49.9s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=distance, total=  50.8s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=distance, total=  51.9s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=distance, total=  49.5s
# [CV] algorithm=ball_tree, leaf_size=5, p=2, weights=distance .........
# [CV]  algorithm=ball_tree, leaf_size=5, p=2, weights=distance, total=  50.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=uniform, total=  43.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=uniform, total=  43.3s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=uniform, total=  43.9s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=uniform, total=  43.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=uniform, total=  42.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=distance, total=  42.6s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=distance, total=  42.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=distance, total=  43.3s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=distance, total=  42.2s
# [CV] algorithm=ball_tree, leaf_size=10, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=1, weights=distance, total=  41.2s
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=uniform, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=uniform, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=uniform, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=uniform, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=uniform, total=  59.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=distance, total=  59.5s
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=distance, total= 1.0min
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=distance, total=  58.8s
# [CV] algorithm=ball_tree, leaf_size=10, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=10, p=2, weights=distance, total=  59.0s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=uniform, total=  56.4s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=uniform, total=  57.3s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=uniform, total=  56.5s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=uniform, total=  55.5s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=uniform, total=  54.4s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=distance, total=  54.6s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=distance, total=  53.7s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=distance, total=  55.1s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=distance, total=  54.0s
# [CV] algorithm=ball_tree, leaf_size=15, p=1, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=1, weights=distance, total=  53.9s
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=uniform, total= 1.3min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=uniform, total= 1.3min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=uniform .........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=distance, total= 1.2min
# [CV] algorithm=ball_tree, leaf_size=15, p=2, weights=distance ........
# [CV]  algorithm=ball_tree, leaf_size=15, p=2, weights=distance, total= 1.3min
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=uniform, total=  22.3s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=uniform, total=  21.7s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=uniform, total=  22.0s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=uniform, total=  21.4s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=uniform, total=  21.7s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=distance, total=  20.8s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=distance, total=  20.8s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=distance, total=  21.1s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=distance, total=  20.7s
# [CV] algorithm=kd_tree, leaf_size=1, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=1, weights=distance, total=  20.6s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=uniform, total=  40.4s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=uniform, total=  39.6s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=uniform, total=  40.2s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=uniform, total=  39.2s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=uniform, total=  39.6s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=distance, total=  39.1s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=distance, total=  39.0s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=distance, total=  39.4s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=distance, total=  39.1s
# [CV] algorithm=kd_tree, leaf_size=1, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=1, p=2, weights=distance, total=  38.9s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=uniform, total=  20.0s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=uniform, total=  20.1s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=uniform, total=  20.4s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=uniform, total=  19.7s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=uniform, total=  19.8s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=distance, total=  19.4s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=distance, total=  19.2s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=distance, total=  19.4s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=distance, total=  19.0s
# [CV] algorithm=kd_tree, leaf_size=5, p=1, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=1, weights=distance, total=  18.9s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=uniform, total=  30.8s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=uniform, total=  30.2s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=uniform, total=  30.6s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=uniform, total=  29.8s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=uniform ............
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=uniform, total=  29.9s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=distance, total=  29.4s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=distance, total=  30.0s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=distance, total=  29.8s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=distance, total=  29.3s
# [CV] algorithm=kd_tree, leaf_size=5, p=2, weights=distance ...........
# [CV]  algorithm=kd_tree, leaf_size=5, p=2, weights=distance, total=  29.1s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=uniform, total=  21.2s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=uniform, total=  20.9s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=uniform, total=  21.6s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=uniform, total=  21.7s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=uniform, total=  20.7s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=distance, total=  19.7s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=distance, total=  19.7s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=distance, total=  20.4s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=distance, total=  19.6s
# [CV] algorithm=kd_tree, leaf_size=10, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=1, weights=distance, total=  19.7s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=uniform, total=  26.0s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=uniform, total=  25.5s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=uniform, total=  25.9s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=uniform, total=  25.3s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=uniform, total=  25.4s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=distance, total=  24.7s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=distance, total=  25.5s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=distance, total=  25.0s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=distance, total=  24.2s
# [CV] algorithm=kd_tree, leaf_size=10, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=10, p=2, weights=distance, total=  24.2s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=uniform, total=  23.1s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=uniform, total=  23.2s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=uniform, total=  23.2s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=uniform, total=  22.7s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=uniform, total=  23.2s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=distance, total=  29.1s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=distance, total=  28.0s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=distance, total=  29.1s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=distance, total=  32.6s
# [CV] algorithm=kd_tree, leaf_size=15, p=1, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=1, weights=distance, total=  30.6s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=uniform, total=  30.9s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=uniform, total=  30.4s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=uniform, total=  30.6s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=uniform, total=  29.8s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=uniform ...........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=uniform, total=  29.9s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=distance, total=  29.7s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=distance, total=  28.1s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=distance, total=  29.4s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=distance, total=  29.1s
# [CV] algorithm=kd_tree, leaf_size=15, p=2, weights=distance ..........
# [CV]  algorithm=kd_tree, leaf_size=15, p=2, weights=distance, total=  27.0s
# [CV] algorithm=brute, leaf_size=1, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=uniform, total= 1.7min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=uniform, total= 1.7min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=uniform, total= 1.7min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=uniform, total= 1.6min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=uniform, total= 1.8min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=distance, total= 1.8min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=distance, total= 1.9min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=distance, total= 1.8min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=distance, total= 1.7min
# [CV] algorithm=brute, leaf_size=1, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=1, weights=distance, total= 1.7min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=uniform, total= 1.5min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=uniform, total= 1.1min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=uniform, total= 1.1min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=uniform, total= 1.0min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=uniform, total=  57.7s
# [CV] algorithm=brute, leaf_size=1, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=distance, total= 1.0min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=distance, total=  59.3s
# [CV] algorithm=brute, leaf_size=1, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=distance, total=  58.5s
# [CV] algorithm=brute, leaf_size=1, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=distance, total= 1.1min
# [CV] algorithm=brute, leaf_size=1, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=1, p=2, weights=distance, total=  54.6s
# [CV] algorithm=brute, leaf_size=5, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=uniform, total= 1.5min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=uniform, total= 1.6min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=uniform, total= 1.6min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=uniform, total= 1.5min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=distance, total= 1.7min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=distance, total= 1.7min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=distance, total= 1.7min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=distance, total= 1.7min
# [CV] algorithm=brute, leaf_size=5, p=1, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=1, weights=distance, total= 2.0min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=uniform, total= 1.2min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=uniform ..............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=uniform, total= 1.1min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=distance, total= 1.1min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=distance, total= 1.1min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=distance, total= 1.1min
# [CV] algorithm=brute, leaf_size=5, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=distance, total=  50.5s
# [CV] algorithm=brute, leaf_size=5, p=2, weights=distance .............
# [CV]  algorithm=brute, leaf_size=5, p=2, weights=distance, total=  51.1s
# [CV] algorithm=brute, leaf_size=10, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=uniform, total= 1.3min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=distance, total= 1.4min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=distance, total= 1.4min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=distance, total= 1.3min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=distance, total= 1.3min
# [CV] algorithm=brute, leaf_size=10, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=1, weights=distance, total= 1.3min
# [CV] algorithm=brute, leaf_size=10, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=uniform, total=  48.4s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=uniform, total=  48.3s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=uniform, total=  49.7s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=uniform, total=  49.0s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=uniform, total=  49.3s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=distance, total=  50.0s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=distance, total=  52.2s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=distance, total=  53.3s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=distance, total=  51.9s
# [CV] algorithm=brute, leaf_size=10, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=10, p=2, weights=distance, total=  51.3s
# [CV] algorithm=brute, leaf_size=15, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=uniform, total= 1.3min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=uniform, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=distance, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=distance, total= 1.3min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=distance, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=distance, total= 1.3min
# [CV] algorithm=brute, leaf_size=15, p=1, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=1, weights=distance, total= 1.4min
# [CV] algorithm=brute, leaf_size=15, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=uniform, total=  51.9s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=uniform, total=  52.1s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=uniform, total=  54.5s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=uniform, total=  56.3s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=uniform .............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=uniform, total=  52.9s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=distance, total=  51.7s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=distance, total=  49.9s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=distance, total=  50.4s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=distance, total=  49.4s
# [CV] algorithm=brute, leaf_size=15, p=2, weights=distance ............
# [CV]  algorithm=brute, leaf_size=15, p=2, weights=distance, total=  47.8s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=uniform, total=  21.6s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=uniform, total=  21.5s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=uniform, total=  21.7s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=uniform, total=  21.3s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=uniform, total=  21.3s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=distance, total=  20.8s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=distance, total=  20.7s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=distance, total=  20.7s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=distance, total=  20.4s
# [CV] algorithm=auto, leaf_size=1, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=1, weights=distance, total=  20.5s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=uniform, total=  40.1s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=uniform, total=  39.9s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=uniform, total=  40.5s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=uniform, total=  39.6s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=uniform, total=  39.1s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=distance, total=  39.0s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=distance, total=  38.8s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=distance, total=  38.9s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=distance, total=  38.2s
# [CV] algorithm=auto, leaf_size=1, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=1, p=2, weights=distance, total=  38.2s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=uniform, total=  19.8s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=uniform, total=  19.8s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=uniform, total=  19.9s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=uniform, total=  19.6s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=uniform, total=  19.7s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=distance, total=  19.2s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=distance, total=  18.8s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=distance, total=  19.4s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=distance, total=  18.9s
# [CV] algorithm=auto, leaf_size=5, p=1, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=1, weights=distance, total=  18.6s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=uniform, total=  30.7s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=uniform, total=  30.1s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=uniform, total=  30.1s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=uniform, total=  30.0s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=uniform ...............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=uniform, total=  29.8s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=distance, total=  29.4s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=distance, total=  29.1s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=distance, total=  29.3s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=distance, total=  28.7s
# [CV] algorithm=auto, leaf_size=5, p=2, weights=distance ..............
# [CV]  algorithm=auto, leaf_size=5, p=2, weights=distance, total=  28.6s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=uniform, total=  20.2s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=uniform, total=  20.7s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=uniform, total=  20.4s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=uniform, total=  20.0s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=uniform, total=  20.0s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=distance, total=  19.4s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=distance, total=  19.4s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=distance, total=  19.5s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=distance, total=  19.4s
# [CV] algorithm=auto, leaf_size=10, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=1, weights=distance, total=  19.2s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=uniform, total=  25.8s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=uniform, total=  25.8s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=uniform, total=  25.9s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=uniform, total=  25.3s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=uniform, total=  25.2s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=distance, total=  24.9s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=distance, total=  25.0s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=distance, total=  24.7s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=distance, total=  24.2s
# [CV] algorithm=auto, leaf_size=10, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=10, p=2, weights=distance, total=  25.0s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=uniform, total=  24.2s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=uniform, total=  24.9s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=uniform, total=  24.0s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=uniform, total=  23.4s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=uniform, total=  23.3s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=distance, total=  22.7s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=distance, total=  22.6s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=distance, total=  23.1s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=distance, total=  22.4s
# [CV] algorithm=auto, leaf_size=15, p=1, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=1, weights=distance, total=  22.5s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=uniform, total=  23.3s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=uniform, total=  23.5s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=uniform, total=  24.1s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=uniform, total=  22.7s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=uniform ..............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=uniform, total=  22.5s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=distance, total=  22.4s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=distance, total=  22.1s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=distance, total=  23.3s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=distance, total=  21.9s
# [CV] algorithm=auto, leaf_size=15, p=2, weights=distance .............
# [CV]  algorithm=auto, leaf_size=15, p=2, weights=distance, total=  21.5s
# [Parallel(n_jobs=1)]: Done 320 out of 320 | elapsed: 233.4min finished
# {'algorithm': 'ball_tree', 'leaf_size': 1, 'p': 1, 'weights': 'distance'}
# 0.7316185012160491

# %% [markdown]
# # Evaluate model

# %% [markdown]
# # Third run

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
pred_train = knn_grid.predict(X_train)
pred_test = knn_grid.predict(X_test)
#print(accuracy_score(y_test, y_pred))
print('Train accuracy:', knn_grid.score(X_train, y_train))
print('Test accuracy:', knn_grid.score(X_test, y_test))
print('Train ROC_AUC:', roc_auc_score(y_train, knn_grid.predict_proba(X_train), average='macro', multi_class='ovr'))
print('Test ROC_AUC:', roc_auc_score(y_test, knn_grid.predict_proba(X_test), average='macro', multi_class='ovr'))
# Out:
# Train accuracy: 1.0
# Test accuracy: 0.7416120888368519
# Train ROC_AUC: 1.0
# Test ROC_AUC: 0.9461147509719237

# %%
from sklearn.multiclass import OneVsRestClassifier
knn = neighbors.KNeighborsClassifier(algorithm='ball_tree', leaf_size=1, p=1, weights='distance')
knn_clf = OneVsRestClassifier(knn)
knn_clf.fit(X_train, y_train)
y_pred_train = knn_clf.predict(X_train)
y_pred_test = knn_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, y_pred_train))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      6750
#            2       1.00      1.00      1.00      6755
#            3       1.00      1.00      1.00      6736
#            4       1.00      1.00      1.00      6722
#            5       1.00      1.00      1.00      6749
#            6       1.00      1.00      1.00      6712
#            7       1.00      1.00      1.00      6721
#            8       1.00      1.00      1.00      6724
#            9       1.00      1.00      1.00      4213
#           10       1.00      1.00      1.00      3042
#           12       1.00      1.00      1.00     48198
#
#     accuracy                           1.00    109322
#    macro avg       1.00      1.00      1.00    109322
# weighted avg       1.00      1.00      1.00    109322
#
#               precision    recall  f1-score   support
#
#            1       0.78      0.77      0.77      1650
#            2       0.76      0.77      0.77      1645
#            3       0.77      0.76      0.76      1664
#            4       0.70      0.76      0.73      1678
#            5       0.67      0.72      0.70      1651
#            6       0.72      0.75      0.73      1688
#            7       0.66      0.59      0.62      1679
#            8       0.74      0.76      0.75      1676
#            9       0.63      0.51      0.56      1067
#           10       0.80      0.65      0.72       751
#           12       0.76      0.78      0.77     12182
#
#     accuracy                           0.74     27331
#    macro avg       0.73      0.71      0.72     27331
# weighted avg       0.74      0.74      0.74     27331

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[1268   62   10    1    1    0    0    0    0   17  291]
#  [  47 1274   47    1    0    0    0    1    0    4  271]
#  [  10   37 1261    4    0    8    2    2    1    2  337]
#  [   0    0    0 1281  120    6   10    5    1    0  255]
#  [   0    0    0  112 1192   93   17    2    8    0  227]
#  [   3    0    6   23   71 1261   35   11   20    0  258]
#  [   0    0    0   18   27   44  986   13  132    2  457]
#  [   0    0    1    7    4    7   15 1270   11    0  361]
#  [   0    0    1   12   30   64  144    6  539    1  270]
#  [  40   19    9    0    0    0    2    1    1  485  194]
#  [ 262  284  305  364  324  261  283  409  144   94 9452]]
