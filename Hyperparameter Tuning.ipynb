# %%
# Import packages
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load and preprocess data

# %%
# Load datasets
df = pd.read_excel('Dokumenter\ChildrenWristFeaturesV2_TSF_new.xlsx')
df.fillna(df.mean(), inplace=True)

# %%
# Initialize features and targets/labels
X = df.iloc[:, 0:32]
Y = df.iloc[:, 32]

# Splits datasets into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Data preprocessing, scaling datasets/standardization
scal_data = StandardScaler()
X_train = scal_data.fit_transform(X_train)
X_test = scal_data.transform(X_test)

# %% [markdown]
# # Hyperparameter tuning

# %%
# Tuning on the n_estimators parameter
from sklearn.ensemble import RandomForestClassifier
import  matplotlib.pyplot as plt
train_scores_estimator = []
test_scores_estimator = []
rf = RandomForestClassifier(warm_start=True, random_state=0)
estimator_range = range(10, 500, 40)
for n_estimators in estimator_range:
    rf.n_estimators = n_estimators
    rf.fit(X_train, y_train)
    train_scores_estimator.append(rf.score(X_train, y_train))
    test_scores_estimator.append(rf.score(X_test, y_test))

# %%
plt.figure(figsize=(7,5))
plt.plot(estimator_range, test_scores_estimator, label="test scores")
plt.plot(estimator_range, train_scores_estimator, label="train scores")
plt.ylabel("accuracy", fontsize=20)
plt.xlabel("n_estimators", fontsize=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(fontsize=20)

# %%
# Tuning on the max_features parameter
from sklearn.ensemble import RandomForestClassifier
import  matplotlib.pyplot as plt
train_scores_features = []
test_scores_features = []
rf = RandomForestClassifier(random_state=0)
features_range = range(1, 32, 4)
for max_features in features_range:
    rf.max_features = max_features
    rf.fit(X_train, y_train)
    train_scores_features.append(rf.score(X_train, y_train))
    test_scores_features.append(rf.score(X_test, y_test))

# %%
plt.figure(figsize=(10,5))
plt.plot(features_range, test_scores_features, label="test scores")
plt.plot(features_range, train_scores_features, label="train scores")
plt.ylabel("accuracy", fontsize=20)
plt.xlabel("max_features", fontsize=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(fontsize=20)

# %%
# Tuning on the max_depth parameter
from sklearn.ensemble import RandomForestClassifier
import  matplotlib.pyplot as plt
train_scores_depth = []
test_scores_depth = []
rf = RandomForestClassifier(random_state=0)
depth_range = range(20, 100, 20)
for max_depth in depth_range:
    rf.max_depth = max_depth
    rf.fit(X_train, y_train)
    train_scores_depth.append(rf.score(X_train, y_train))
    test_scores_depth.append(rf.score(X_test, y_test))

# %%
plt.figure(figsize=(7,5))
plt.plot(depth_range, test_scores_depth, label="test scores")
plt.plot(depth_range, train_scores_depth, label="train scores")
plt.ylabel("accuracy", fontsize=20)
plt.xlabel("max_depth", fontsize=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(fontsize=20)

# %%
# Tuning on the min_samples_split parameter
from sklearn.ensemble import RandomForestClassifier
import  matplotlib.pyplot as plt
train_scores_split = []
test_scores_split = []
rf = RandomForestClassifier(random_state=0)
spilt_range = range(10, 50, 10)
for min_samples_split in spilt_range:
    rf.min_samples_split = min_samples_split
    rf.fit(X_train, y_train)
    train_scores_split.append(rf.score(X_train, y_train))
    test_scores_split.append(rf.score(X_test, y_test))

# %%
plt.figure(figsize=(7,5))
plt.plot(spilt_range, test_scores_split, label="test scores")
plt.plot(spilt_range, train_scores_split, label="train scores")
plt.ylabel("accuracy", fontsize=20)
plt.xlabel("min_samples_split", fontsize=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(fontsize=20)

# %%
# Tuning on the min_samples_leaf parameter
from sklearn.ensemble import RandomForestClassifier
import  matplotlib.pyplot as plt
train_scores_leaf = []
test_scores_leaf = []
rf = RandomForestClassifier(random_state=0)
leaf_range = range(2, 20, 4)
for min_samples_leaf in leaf_range:
    rf.min_samples_leaf = min_samples_leaf
    rf.fit(X_train, y_train)
    train_scores_leaf.append(rf.score(X_train, y_train))
    test_scores_leaf.append(rf.score(X_test, y_test))

# %%
plt.figure(figsize=(7,5))
plt.plot(leaf_range, test_scores_leaf, label="test scores")
plt.plot(leaf_range, train_scores_leaf, label="train scores")
plt.ylabel("accuracy", fontsize=20)
plt.xlabel("min_samples_leaf", fontsize=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.legend(fontsize=20)
